# %%
import numpy as np
import pandas as pd

# %%
filepath= r"./output/"
df_table_per_flux = pd.read_csv(filepath+'table_per_flux_h2.csv',index_col=0)
df_table_per_flux
# Out:
#                  deltaH2  surf_h2_per_h2_flux  surf_ch4_per_h2_flux  \
# GFDL-emi      197.030980             6.955456              0.999843
# GFDL_nudge     30.535530             6.978819              1.143627
# INCA            7.225180             7.360370              1.127318
# OSLOCTM3        8.538529             6.230581              1.125833
# OSLOCTM3-emi   13.760425             6.478510              1.151718
# UKCA            6.866690             7.796915              1.332089
# WACCM6-2deg     9.928230             5.356242              1.186818
#
#               ch4_flux_per_h2_flux  ch4_rf_per_h2_flux  \
# GFDL-emi                  0.211803            0.385219
# GFDL_nudge                0.260552            0.440617
# INCA                      0.294061            0.434333
# OSLOCTM3                  0.312144            0.433761
# OSLOCTM3-emi              0.319320            0.443734
# UKCA                      0.382196            0.513227
# WACCM6-2deg               0.330084            0.457257
#
#               trop_du_ozone_per_h2_flux  strat_du_ozone_per_h2_flux  \
# GFDL-emi                       7.968127                    5.228261
# GFDL_nudge                     4.088931                   -2.424079
# INCA                           3.928001                   -5.564394
# OSLOCTM3                       4.477085                    0.773077
# OSLOCTM3-emi                   4.608446                    0.754902
# UKCA                           4.625690                         NaN
# WACCM6-2deg                    3.307870                   -1.101545
#
#               ozone_rf_per_h2_flux  h2o_rf_per_h2_flux  aerosol_rf_per_h2_flux
# GFDL-emi                  0.388035            0.250417               -0.073085
# GFDL_nudge                0.209693            0.161058               -0.004061
# INCA                      0.146709            0.114046                0.030311
# OSLOCTM3                  0.218328            0.173332               -0.032793
# OSLOCTM3-emi              0.222697            0.176593               -0.028342
# UKCA                      0.165844                 NaN                     NaN
# WACCM6-2deg               0.176255            0.051570                     NaN

# %%
filepath= r"./output/"
df_table_per_flux_ch4=pd.read_csv(filepath+'table_per_flux_ch4.csv',index_col=0)
df_table_per_flux_ch4
# Out:
#                deltaCH4  surf_ch4_per_ch4_flux  h2_flux_per_ch4_flux  \
# GFDL-emi       3.099273              64.404741            -64.282442
# GFDL_nudge    41.383621               4.389241              0.012624
# INCA          47.296567               3.833619              0.010519
# OSLOCTM3      50.266446               3.606780              0.014884
# OSLOCTM3-emi  50.266446               3.606780              0.014884
# UKCA          51.827390               3.485358              0.014540
# WACCM6-2deg   50.280825               3.595506              0.017124
#
#               trop_du_ozone_per_ch4_flux  strat_du_ozone_per_ch4_flux  \
# GFDL-emi                      506.560048                   332.377736
# GFDL_nudge                     16.044298                    18.790720
# INCA                           11.279251                     5.294362
# OSLOCTM3                       16.527967                    16.441907
# OSLOCTM3-emi                   16.527967                    16.441907
# UKCA                           13.557889                          NaN
# WACCM6-2deg                    17.415513                    15.885782
#
#               ozone_rf_per_ch4_flux  h2o_rf_per_ch4_flux  \
# GFDL-emi                  24.668689            15.919863
# GFDL_nudge                 0.806974             0.483283
# INCA                       0.466222             0.140074
# OSLOCTM3                   0.816411             0.200929
# OSLOCTM3-emi               0.816411             0.200929
# UKCA                       0.468135                  NaN
# WACCM6-2deg                0.848769             0.074860
#
#               aerosol_rf_per_ch4_flux
# GFDL-emi                    -4.646251
# GFDL_nudge                  -0.008989
# INCA                         0.055395
# OSLOCTM3                    -0.022082
# OSLOCTM3-emi                -0.022082
# UKCA                              NaN
# WACCM6-2deg                       NaN

# %%
#Tg H2/Tg CH4  * Tg CH4/Tg H2  #Normalisere resultatene for 1 Tg CH4 og multiplisere med flux H2 * flux H2/flux CH4
frac =  df_table_per_flux['deltaH2']/df_table_per_flux_ch4['deltaCH4']*df_table_per_flux['ch4_flux_per_h2_flux']   
frac.drop('GFDL-emi')
# Out:
# GFDL_nudge      0.192252
# INCA            0.044922
# OSLOCTM3        0.053022
# OSLOCTM3-emi    0.087414
# UKCA            0.050638
# WACCM6-2deg     0.065177
# dtype: float64

# %%
#(Diff_OH_H2 + frac * Diff_OH_CH4)/CNTR_OH

# %%
file = 'H2_surfconc.txt'
df_h2_surfconc = pd.read_csv(r"./input/" + file, sep=';',index_col=0,header=0)
delta = df_h2_surfconc.loc['10H2']-df_h2_surfconc.loc['CTRL']
delta.name = 'deltaH2'
df_h2_surfconc = df_h2_surfconc.append(delta)
df_h2_surfconc
# Out:
#           OSLOCTM3  WACCM6-2deg     INCA     GFDL-emi  OSLOCTM3-emi     UKCA  \
# Scenario
# CTRL         531.7      531.776  531.793   542.055572    566.952303  536.635
# 10H2         584.9      584.954  584.973  1912.495889    656.099352  590.174
# deltaH2       53.2       53.178   53.180  1370.440317     89.147049   53.539
#
#           GFDL_nudge
# Scenario
# CTRL      533.385985
# 10H2      746.487929
# deltaH2   213.101944

# %%
print(df_h2_surfconc.loc['deltaH2']/53.1)
# Out:
# OSLOCTM3         1.001883
# WACCM6-2deg      1.001469
# INCA             1.001507
# GFDL-emi        25.808669
# OSLOCTM3-emi     1.678852
# UKCA             1.008267
# GFDL_nudge       4.013219
# Name: deltaH2, dtype: float64

# %% [markdown]
# Divide (Diff_OH_H2 + frac * Diff_OH_CH4)/CNTR_OH by this numbers.
